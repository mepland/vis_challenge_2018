# %% [markdown]
# # Interactively Graphing Duke PhD Committee Interdisciplinary Connections

# %%
import json; from visJS2jupyter import visJS_module
with open('nodes.json', 'r') as fp: nodes_dict = json.load(fp)
with open('edges.json', 'r') as fp: edges_dict = json.load(fp)
visJS_module.visjs_network(nodes_dict, edges_dict,
                           node_size_field='node_size', node_size_transform='Math.log', node_size_multiplier=2,
                           node_font_size=0,
                           edge_width=9, edge_title_field="title",
                           graph_title="Interactive Duke Interdisciplinary Connections (All Years)",
                           graph_width = 940, graph_height = 600, border_color='black',
                           tooltip_delay = 0, graph_id = 0, config_enabled=False)
# Out:
# <!doctype html><html><head>  <title>Network | Basic usage</title></head><body><script type="text/javascript">function setUpFrame() {     var frame = window.frames["style_file0"];    frame.runVis([{"node_shape": "triangle", "degree": 3.0, "title": "<center><b>Psychiatry & Behavioral Sciences</b><br>School of Medicine<br>Neuro<br>Node Weight: 3229<br>Interdis Frac: 0.960</center>", "color": "rgba(256, 127, 14, 1.0)", "node_size": 3229.0, "y": 976.179535096762, "x": -47.913802922126415, "border_width": 0, "id": 50000900}, {"node_shape": "square", "degree": 3.0, "title": "<center><b>Civil and Environmental Engineering</b><br>Pratt School of Engineering<br>Physical Sciences<br>Node Weight: 2716<br>Interdis Frac: 0.900</center>", "color": "rgba(44, 160, 44, 1.0)", "node_size": 2716.0, "y": 920.3945047946231, "x": -98.78445974404981, "border_width": 0, "id": 50000393}, {"node_shape": "square", "degree": 3.0, "title": "<center><b>Electrical and Computer Engineering</b><br>Pratt School of Engineering<br>Physical Sciences<br>Node Weight: 4888<br>Interdis Frac: 0.855</center>", "color": "rgba(44, 160, 44, 1.0)", "node_size": 4888.0, "y": 969.0638238869132, "x": -127.4121809203324, "border_width": 0, "id": 50000394}, {"node_shape": "triangle", "degree": 3.0, "title": "<center><b>Regeneration Next Initiative</b><br>School of Medicine<br>\"School of Medicine\"<br>Node Weight: 4533<br>Interdis Frac: 0.960</center>", "color": "rgba(31, 119, 180, 1.0)", "node_size": 4533.0, "y": 1079.1357059731488, "x": -142.17914797219711, "border_width": 0, "id": 51007575}, {"node_shape": "square", "degree": 3.0, "title": "<center><b>Mechanical Engineering and Materials Science</b><br>Pratt School of Engineering<br>Physical Sciences<br>Node Weight: 2416<br>Interdis Frac: 0.894</center>", "color": "rgba(44, 160, 44, 1.0)", "node_size": 2416.0, "y": 968.4102804353192, "x": -156.27715147483423, "border_width": 0, "id": 50000396}, {"node_shape": "triangleDown", "degree": 3.0, "title": "<center><b>Duke University Energy Initiative</b><br>Institutes & Provost's Academic Units<br>Physical Sciences<br>Node Weight: 7961<br>Interdis Frac: 0.938</center>", "color": "rgba(44, 160, 44, 1.0)", "node_size": 7961.0, "y": 970.5513200177339, "x": -80.5034475495954, "border_width": 0, "id": 50691597}, {"node_shape": "square", "degree": 3.0, "title": "<center><b>Biomedical Engineering</b><br>Pratt School of Engineering<br>\"School of Medicine\"<br>Node Weight: 6388<br>Interdis Frac: 0.913</center>", "color": "rgba(31, 119, 180, 1.0)", "node_size": 6388.0, "y": 1043.0335397821145, "x": -136.4021757799278, "border_width": 0, "id": 50000398}, {"node_shape": "star", "degree": 3.0, "title": "<center><b>Fuqua School of Business</b><br>Fuqua School of Business<br>Social Science / Health, Pro Schools<br>Node Weight: 1536<br>Interdis Frac: 0.747</center>", "color": "rgba(214, 39, 40, 1.0)", "node_size": 1536.0, "y": 1005.4002842652152, "x": 58.35960277742617, "border_width": 0, "id": 50000403}, {"node_shape": "triangle", "degree": 3.0, "title": "<center><b>Radiology</b><br>School of Medicine<br>\"School of Medicine\"<br>Node Weight: 1691<br>Interdis Frac: 0.913</center>", "color": "rgba(31, 119, 180, 1.0)", "node_size": 1691.0, "y": 999.1686699366579, "x": -212.50158722458966, "border_width": 0, "id": 50000925}, {"node_shape": "triangle", "degree": 3.0, "title": "<center><b>Oncology</b><br>School of Medicine<br>\"School of Medicine\"<br>Node Weight: 2535<br>Interdis Frac: 0.957</center>", "color": "rgba(31, 119, 180, 1.0)", "node_size": 2535.0, "y": 1055.4670170487645, "x": -226.93686634569357, "border_width": 0, "id": 50000936}, {"node_shape": "triangle", "degree": 3.0, "title": "<center><b>Duke Center for Human Genome Variation</b><br>School of Medicine<br>\"School of Medicine\"<br>Node Weight: 62<br>Interdis Frac: 1.000</center>", "color": "rgba(31, 119, 180, 1.0)", "node_size": 62.0, "y": 813.3559912862639, "x": -497.17784601586544, "border_width": 0, "id": 50586670}, {"node_shape": ...
